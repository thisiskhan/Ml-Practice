# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from datetime import datetime, date, time

# %%
#Read Data 
import pandas as pd
#import numpy as np
df = pd.read_csv('netflix_titles.csv')

# %%
df.head(n = 10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df.head(n = 100)
# Out:
#    show_id     type           title           director  \
# 0       s1  TV Show              3%                NaN
# 1       s2    Movie            7:19  Jorge Michel Grau
# 2       s3    Movie           23:59       Gilbert Chan
# 3       s4    Movie               9        Shane Acker
# 4       s5    Movie              21     Robert Luketic
# ..     ...      ...             ...                ...
# 95     s96  TV Show        28 Moons                NaN
# 96     s97    Movie  3 Days to Kill                McG
# 97     s98    Movie     3 Deewarein    Nagesh Kukunoor
# 98     s99    Movie   3 Generations        Gaby Dellal
# 99    s100    Movie      3 Heroines     Iman Brotoseno
#
#                                                  cast  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %%
df.describe(include= "all")
# Out:
#        show_id   type           title                director  \
# count     7787   7787            7787                    5398
# unique    7787      2            7787                    4049
# top      s6355  Movie  Dolphin Tale 2  Raúl Campos, Jan Suter
# freq         1   5377               1                      18
# mean       NaN    NaN             NaN                     NaN
# std        NaN    NaN             NaN                     NaN
# min        NaN    NaN             NaN                     NaN
# 25%        NaN    NaN             NaN                     NaN
# 50%        NaN    NaN             NaN                     NaN
# 75%        NaN    NaN             NaN                     NaN
# max        NaN    NaN             NaN                     NaN
#
#                       cast        country       date_added  release_year  \
# count                 7069           7280             7777   7787.000000
# ...

# %%
df.head(n = 10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.describe(include = "all")
# Out:
#        show_id   type           title                director  \
# count     7787   7787            7787                    5398
# unique    7787      2            7787                    4049
# top      s6355  Movie  Dolphin Tale 2  Raúl Campos, Jan Suter
# freq         1   5377               1                      18
# mean       NaN    NaN             NaN                     NaN
# std        NaN    NaN             NaN                     NaN
# min        NaN    NaN             NaN                     NaN
# 25%        NaN    NaN             NaN                     NaN
# 50%        NaN    NaN             NaN                     NaN
# 75%        NaN    NaN             NaN                     NaN
# max        NaN    NaN             NaN                     NaN
#
#                       cast        country       date_added  release_year  \
# count                 7069           7280             7777   7787.000000
# ...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
temp = pd.DataFrame({
    "User Id" : ["qwertyuiop2345", "qwertyuiopdf34567", "asdfghjklerfgb345", "qazwsxedfcrfvtgb"],
    "username" : ["Raza", "Baba69", "Ziyan", "Shayan"],
    "Location"  : ["Mumbai" , "India" , "Trombay" , "CheatCamp"],
})

# %%
temp
# Out:
#              User Id username   Location
# 0     qwertyuiop2345     Raza     Mumbai
# 1  qwertyuiopdf34567   Baba69      India
# 2  asdfghjklerfgb345    Ziyan    Trombay
# 3   qazwsxedfcrfvtgb   Shayan  CheatCamp

# %%
df["country"].value_counts()
# Out:
# United States                             2555
# India                                      923
# United Kingdom                             397
# Japan                                      226
# South Korea                                183
#                                           ...
# Germany, United States, Canada               1
# Canada, Luxembourg                           1
# Soviet Union, India                          1
# France, Lebanon, United Kingdom              1
# Bulgaria, United States, Spain, Canada       1
# Name: country, Length: 681, dtype: int64

# %%
country = df["country"]

# %%
country.head(  n  = 20)
# Out:
# 0                             Brazil
# 1                             Mexico
# 2                          Singapore
# 3                      United States
# 4                      United States
# 5                             Turkey
# 6                              Egypt
# 7                      United States
# 8                              India
# 9                              India
# 10                     United States
# 11             Poland, United States
# 12                            Mexico
# 13                          Thailand
# 14                     United States
# 15                           Nigeria
# 16                               NaN
# 17    Norway, Iceland, United States
# 18                             India
# 19                    United Kingdom
# Name: country, dtype: object

# %%
type(df[["title", "cast"]])
# Out:
# pandas.core.frame.DataFrame

# %%
cast_country = df[["cast" , "country","type" , "title"]]

# %%
cast_country.head(n = 20)
# Out:
#                                                  cast  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...
# 9   Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...
# 12                                                NaN
# 13                                 Artiwara Kongmalai
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...

# %%
df.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df["duration"].max()
# Out:
# '99 min'
